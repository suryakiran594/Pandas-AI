# %% [markdown]
# <a href="https://colab.research.google.com/github/suryakiran594/Pandas-AI/blob/main/PandasAI_manipulations_on_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandasai import PandasAI

# %%
pip install pandasai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 42.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 2.0.1 which is incompatible.
# ...

# %%
pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.7 MB/s eta 0:00:00
# ...

# %%
#Sample DataSet

df=pd.DataFrame({'Country':['United States','United Kindom','France','Germany','Italy','Spain',
                            'Canada','Australia','Ireland','Denmark'],
                'GDP':[21400000,2940000,2830000,3870000,2160000,1350000,1780000,516000,1400000,1200000],
                'Happiness_Index':[7.3,7.2,6.5,7.0,6.0,6.0,3.7,3.7,5.9,5.0]
                })
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm)
pandas_ai.run(df,prompt='which are the 5 least happiest countries?')
# Out:
# 'According to the data, the five countries that rank the least happiest are Canada, Australia, Denmark, Ireland, and Italy.'

# %%
  #Sample DataSet

df=pd.DataFrame({'Country':['United States','United Kindom','France','Germany','Italy','Spain',
                            'Canada','Australia','Ireland','Denmark'],
                'GDP':[214000,2940000,2830000,3870000,2160000,1350000,1780000,516000,1400000,1200000],
                'Happiness_Index':[7.3,7.2,6.5,7.0,6.0,6.0,3.7,3.7,5.9,5.0]
                })
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,'list out the countries given in the dataframe ?')
#print (response)
# Out:
# ['United States',
#  'United Kindom',
#  'France',
#  'Germany',
#  'Italy',
#  'Spain',
#  'Canada',
#  'Australia',
#  'Ireland',
#  'Denmark']

# %%
  #Sample DataSet

"""df=pd.DataFrame({'Country':['United States','United Kindom','France','Germany','Italy','Spain',
                            'Canada','Australia','Ireland','Denmark'],
                'GDP':[214000,2940000,2830000,3870000,2160000,1350000,1780000,516000,1400000,1200000],
                'Happiness_Index':[7.3,7.2,6.5,7.0,6.0,6.0,3.7,3.7,5.9,5.0]
                })"""
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,' How many loans are from men and have been paid off?')
#print (response)
# Out:
# 247

# %%
  #Sample DataSet

"""df=pd.DataFrame({'Country':['United States','United Kindom','France','Germany','Italy','Spain',
                            'Canada','Australia','Ireland','Denmark'],
                'GDP':[214000,2940000,2830000,3870000,2160000,1350000,1780000,516000,1400000,1200000],
                'Happiness_Index':[7.3,7.2,6.5,7.0,6.0,6.0,3.7,3.7,5.9,5.0]
                })"""
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,' list out the top 100 number of loans in the given csv file')
#print (response)
# Out:
# xqd20166231    1
# xqd20160330    1
# xqd20160343    1
# xqd20160342    1
# xqd20160341    1
#               ..
# xqd20160283    1
# xqd20160284    1
# xqd20160311    1
# xqd20160310    1
# xqd20160309    1
# Name: Loan_ID, Length: 100, dtype: int64

# %%
#Sample DataSet
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,' what is the highest loan amount sanctined in the given csv file')
#print (response)
# Out:
# 1000

# %% [markdown]
# list out all the records where age in less than 35 in the given csv file

# %%
#Sample DataSet
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,' list out all the records where age in less than 35 in the given csv file')
#print (response)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# 6    xqd20160007             PAIDOFF       1000     30       9/9/2016
# 8    xqd20160909             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 494  xqd20160495  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %% [markdown]
# Delete all the null values in the given csv file

# %%
#Sample DataSet
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,'delete all the null values in the given csv file')

# %% [markdown]
# Respose: Deleted all the null values in the DataFrame

# %%
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 400  xqd20160401  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 401  xqd20160402  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 402  xqd20320403  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 403  xqd20160404  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 404  xqd20190405  COLLECTION_PAIDOFF        800     15       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID           0
# loan_status       0
# Principal         0
# terms             0
# effective_date    0
# due_date          0
# paid_off_time     0
# past_due_days     0
# age               0
# education         0
# Gender            0
# dtype: int64

# %% [markdown]
# Sort the list according to the highest prinpal amount and highest terms in the given csv file

# %%
#Sample DataSet
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,'sort the list according to the highest prinpal amount and highest terms the given csv file')
#print (response)
# Out:
#          Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0    xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1    xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2    xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 4    xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 6    xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# ..           ...         ...        ...    ...            ...        ...
# 10   xqd20160011     PAIDOFF        300      7      9/10/2016  9/16/2016
# 68   xqd20160069     PAIDOFF        300      7      9/11/2016  9/17/2016
# 147  xqd20160148     PAIDOFF        300      7      9/12/2016  9/18/2016
# 181  xqd20160182     PAIDOFF        300      7      9/12/2016  9/18/2016
# 208  xqd20160209     PAIDOFF        300      7      9/12/2016  9/18/2016
#
#        paid_off_time  past_due_days  age             education  Gender
# ...

# %% [markdown]
# slice the effective_date column into three different columns effective_day effective_month effective_year in the given csv file

# %%
#Sample DataSet
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,'slice the effective_date column into three different columns effective_day effective_month effective_year in the given csv file')
#print (response)
# Out:
# ''

# %%
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
#Sample DataSet
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df,'remove all the null values in the given csv file')
#print (response)

# %%
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 400  xqd20160401  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 401  xqd20160402  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 402  xqd20320403  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 403  xqd20160404  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 404  xqd20190405  COLLECTION_PAIDOFF        800     15       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
df1=df.copy()

# %%
df1
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 400  xqd20160401  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 401  xqd20160402  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 402  xqd20320403  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 403  xqd20160404  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 404  xqd20190405  COLLECTION_PAIDOFF        800     15       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %% [markdown]
# sort the list in decending order according to past_due_days the given csv file

# %%
#Sample DataSet
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
#df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df1,'sort the list in decending order according to past_due_days the given csv file')
#print (response)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 486  xqd20160487  COLLECTION_PAIDOFF        800     15      9/12/2016
# 469  xqd25660470  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 472  xqd20160473  COLLECTION_PAIDOFF        800     15      9/12/2016
# 408  xqd20110409  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 456  xqd20160457  COLLECTION_PAIDOFF       1000     30      9/12/2016
# ..           ...                 ...        ...    ...            ...
# 434  xqd20160435  COLLECTION_PAIDOFF       1000     30      9/11/2016
# 465  xqd20169466  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 426  xqd20160427  COLLECTION_PAIDOFF       1000     30      9/11/2016
# 467  xqd20160468  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 464  xqd20160465  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
df1=df.copy()

# %%
#Sample DataSet
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
#df=pd.read_csv("Loan payments data.csv")
llm= OpenAI(api_token="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")
pandas_ai=PandasAI(llm,verbose=True,conversational=False)
pandas_ai.run(df1,'split the column effective_date in to day month and year with column name effective_day effective_month and effective_year in the given csv file')
#print (response)
# Out:
# ''

# %%
df1
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
df2=df1.copy()
